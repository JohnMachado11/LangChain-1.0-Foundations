# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """
    Search the web for information
    """

    return tavily_client.search(query)

# %%
system_prompt = """
    You are a personal chef. The user will give you a list of ingredients they have left over in their house.

    Using the web search tool, search the web for recipes that can be made with the ingredients they have.

    Return recipe suggestions and eventually the recipe instructions to the user, if requested.
"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response["messages"][-1].content)
# Out:
# Nice—leftover chicken and rice are perfect for quick, comforting meals. Here are several solid options you can choose from (all fairly common to make and great with basic pantry staples):
#
# - One-Pot Creamy Chicken and Rice (stovetop)
#   - Why it’s great: Cozy, creamy texture with minimal cleanup; everything comes together in one pot.
#   - Approx time: 30–40 minutes.
#   - Source idea: Budget Bytes / The Dinner Bite style recipes.
#
# - Chicken Fried Rice (skillet)
#   - Why it’s great: Uses leftover rice crisps up nicely and you can toss in any veggies you’ve got. Very quick.
#   - Approx time: 15–20 minutes.
#   - Source idea: Classic fried rice recipes (RecipeTin Eats, Averie Cooks, etc.).
#
# - Chicken and Rice Casserole (baked)
#   - Why it’s great: Hearty, comforting, and easy to bake in one dish; you can add peas or broccoli for color and nutrition.
#   - Approx time: 45–60 minutes (plus bake time).
#   - Source idea: Various “one-pan” or “casserole” chicken and rice recipes.
#
# - Chicken and Rice Soup (broth-based)
#   - Why it’s great: Light and warming; easy to scale up with more veggies or noodles.
#   - Approx time: 30–45 minutes.
#   - Source idea: Classic chicken and rice soup recipes (some call for cooking the rice separately to keep texture).
#
# - Leftover Chicken and Egg Fried Rice (specific leftover-hack)
#   - Why it’s great: Focused on using leftovers exactly as-is; extra tasty with a few eggs for protein.
#   - Approx time: 15–20 minutes.
#   - Source idea: Leftover chicken and egg fried rice recipes.
#
# Would you like me to pull full step-by-step instructions for one of these? If you tell me which option sounds best (or what ingredients you have on hand besides chicken and rice), I’ll tailor a complete recipe with exact measurements and steps.

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='7feb186f-b92b-4b69-a1a8-87466b803089'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 768, 'prompt_tokens': 202, 'total_tokens': 970, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsZtSPTtc30s8E3bWHP3siptAmU87', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b70c8-1f9b-7960-8bba-1d0f0c02bf10-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_6bQ43MsVkalBUE8vgsFCUCnu', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'one-pot chicken and rice recipe'}, 'id': 'call_2uc3P15l54gPOSQb1wh3BK1k', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_1eP1gpD3zUjV3uSaMRKZbPxQ', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'parameters': 'chicken and rice casserole recipe', 'query': 'chicken and rice casserole recipe'}, 'id': 'call_q0bvNvfUhPgjFOB5XH9aC2sT', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken soup with rice recipe'}, 'id': 'call_nmnyS4E1YC9PrDnaZfecDxfU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 202, 'output_tokens': 768, 'total_tokens': 970, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and ...", "content": "Recipe Ingredients: 2 cups cooked and chilled rice 1 lb chicken breast, cut into small pieces 2 tablespoons vegetable oil 1 small onion", "score": 0.89997756, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8452414, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole", "content": "Home | Recipe Index | Savory | Casserole | Chicken and Rice Casserole. # Chicken and Rice Casserole. This is the best chicken and rice recipe because it’s easy to make with simple ingredients that you can switch up depending on your tastes. It’s what I consider a “leftover” recipe because I use leftover chicken and rice to make it. ## Ingredients for Chicken and Rice Casserole. ## How to make Chicken and Rice Casserole. * I love **peas** in my chicken casserole, but you can swap them out, use **frozen broccoli** instead and call it chicken broccoli and rice casserole. For my chicken and rice casserole you will want to use cooked chicken. ## Chicken and Rice Casserole. Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! ### Chicken and Rice Casserole.", "score": 0.84027237, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14600 subscribers\\n49 likes\\n7853 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.8342047, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "# Chicken Fried Rice. *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.*. I used leftover rotisserie chicken and leftover rice in this. You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. * **Cold rice** - cold rice makes the best fried rice so use leftover rice or cook the rice the night before. ## How To Make Chicken Fried Rice. * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice. Simple and delicious Chicken F ...
#               ToolMessage(content='{"query": "one-pot chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. The dish will thicken as it cools, and you can taste the flavor much better when the chicken and rice is warm vs piping hot, so I like to let the pot sit uncovered for an additional 10 minutes or so before scooping into bowls and serving. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.94314384, "raw_content": null}, {"url": "https://www.budgetbytes.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice", "content": "This Chicken and Rice one pot meal is the kind of comfort food I make time and time again, and it’s definitely moving to the top of my list of favorite recipes. This super simple dish includes juicy chicken thighs coated in herbs and spices (not spicy!), sautéed onions, and long grain white rice cooked in vegetable broth. Since I didn’t add any vegetables *in* the pot with my chicken and rice, I added some roasted broccoli on the side. This hearty and delicious chicken and rice combines rich and flavorful rice with well seasoned chicken or an easy one pot meal. So easy to try many different types of spice profiles- this would be a great base, for instance- for Spanish rice and chicken one pot meal- just get some tomato bouillon and some tomato paste added after the onions would make a really excellent alternative- season the chicken with adobo, beans as a side etc.", "score": 0.9304142, "raw_content": null}, {"url": "https://www.thedinnerbite.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice", "content": "# One Pot Chicken and Rice. This **one pot chicken and rice** recipe is about to become your family’s favourite. ## **One pot chicken and rice recipe**. Although both chicken and rice recipes on the blog were made in my Instant Pot pressure cooker, I’m listening to my readers who haven’t yet joined the Instant Pot bandwagon and showing you how I make stovetop one-pan chicken and rice in easy steps. Today’s recipe is similar to my Instant Pot chicken and rice and I hope you enjoy it as much as we did. ##
com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Quick and Comforting - Iowa Girl Eats", "content": "# Easy Chicken and Rice Soup. Easy Chicken and Rice Soup is a quick and simple soup recipe that the entire family will love. Soup season is 12 months a year at my house, and the recipe that makes the most appearances – even during the dog days of summer – is my **Chicken and Rice Soup** recipe. This brothy a ...
#               AIMessage(content='Nice—leftover chicken and rice are perfect for quick, comforting meals. Here are several solid options you can choose from (all fairly common to make and great with basic pantry staples):\n\n- One-Pot Creamy Chicken and Rice (stovetop)\n  - Why it’s great: Cozy, creamy texture with minimal cleanup; everything comes together in one pot.\n  - Approx time: 30–40 minutes.\n  - Source idea: Budget Bytes / The Dinner Bite style recipes.\n\n- Chicken Fried Rice (skillet)\n  - Why it’s great: Uses leftover rice crisps up nicely and you can toss in any veggies you’ve got. Very quick.\n  - Approx time: 15–20 minutes.\n  - Source idea: Classic fried rice recipes (RecipeTin Eats, Averie Cooks, etc.).\n\n- Chicken and Rice Casserole (baked)\n  - Why it’s great: Hearty, comforting, and easy to bake in one dish; you can add peas or broccoli for color and nutrition.\n  - Approx time: 45–60 minutes (plus bake time).\n  - Source idea: Various “one-pan” or “casserole” chicken and rice recipes.\n\n- Chicken and Rice Soup (broth-based)\n  - Why it’s great: Light and warming; easy to scale up with more veggies or noodles.\n  - Approx time: 30–45 minutes.\n  - Source idea: Classic chicken and rice soup recipes (some call for cooking the rice separately to keep texture).\n\n- Leftover Chicken and Egg Fried Rice (specific leftover-hack)\n  - Why it’s great: Focused on using leftovers exactly as-is; extra tasty with a few eggs for protein.\n  - Approx time: 15–20 minutes.\n  - Source idea: Leftover chicken and egg fried rice recipes.\n\nWould you like me to pull full step-by-step instructions for one of these? If you tell me which option sounds best (or what ingredients you have on hand besides chicken and rice), I’ll tailor a complete recipe with exact measurements and steps.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1839, 'prompt_tokens': 6403, 'total_tokens': 8242, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsZtgLIPqjNoGRncQfUDIsYFD2GhK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b70c8-5579-7250-a634-637befbca289-0', usage_metadata={'input_tokens': 6403, 'output_tokens': 1839, 'total_tokens': 8242, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})]}

# %% [markdown]
# https://smith.langchain.com/public/6a492840-4258-4013-a079-8969b03b5ac1/r

# %% [markdown]
# ## Follow up question using an image

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept=".png", multiple=False) # Use /files/refrigerator.png
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'refrigerator.png', 'type': 'image/png', 'size': 38439, 'content': <memory at 0x131f02680>, 'last_modified': datetime.datetime(2025, 12, 30, 19, 41, 4, 934000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv) # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8") # Convert raw bytes into base64 text string.

# %%
multimodal_question = HumanMessage(
    content=[
        {"type": "text", "text": 
            """
                Tell me what you notice about my refrigerator here?

                Also, from the recipes that you provided, which one is the easiest
                for me to do if I need to store them in my refrigerator?
            """},
        {"type": "image", "base64": img_b64, "mime_type": "image/png"}
    ]
)

response = agent.invoke(
    {"messages": [multimodal_question]},
    config
)

print(response["messages"][-1].content)
# Out:
# Nice, I’ll tackle both parts.
#
# What I notice about your refrigerator (from the image)
# - It looks like a compact/apartment-size fridge with a standard interior layout (shelves, a crisper drawer at the bottom, and door shelves).
# - The unit appears clean and mostly empty, which is great for planning leftovers.
# - The door swings open to the left in the photo, with multiple door trays for bottles or small jars.
# - There isn’t visible produce or dairy inside, so you’ve got space to add a few containers of leftovers or prepared meals.
# - Overall, it’s a basic, no-frills fridge that’s easy to organize if you portion food into airtight containers.
#
# Which of the recipes is the easiest to store in the fridge
# - My pick for easiest storage: Chicken Rice Casserole (the “one-pan baked” option).
#   - Why: It’s a single dish that you can portion out into airtight containers or keep in the baking dish with a lid. It stores well in the fridge for 3–4 days and reheats nicely in the microwave or oven without losing texture.
# - If you’d rather avoid a casserole, the Chicken Fried Rice is also very fridge-friendly: simply store leftovers in an airtight container and reheat in a skillet or microwave. It reheats quickly and doesn’t require separate components.
# - The One-Pot Creamy Chicken and Rice is also convenient for fridge storage, since leftovers stay cohesive in the same pot (just reheat gently with a splash of broth to loosen if needed).
#
# Would you like me to share the full step-by-step recipe for the easiest option (casserole), with exact measurements and a fridge-friendly storage plan? If you tell me how many servings you want to store, I’ll tailor it.

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='7feb186f-b92b-4b69-a1a8-87466b803089'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 768, 'prompt_tokens': 202, 'total_tokens': 970, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsZtSPTtc30s8E3bWHP3siptAmU87', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b70c8-1f9b-7960-8bba-1d0f0c02bf10-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'leftover chicken and rice recipe'}, 'id': 'call_6bQ43MsVkalBUE8vgsFCUCnu', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'one-pot chicken and rice recipe'}, 'id': 'call_2uc3P15l54gPOSQb1wh3BK1k', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken fried rice recipe'}, 'id': 'call_1eP1gpD3zUjV3uSaMRKZbPxQ', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'parameters': 'chicken and rice casserole recipe', 'query': 'chicken and rice casserole recipe'}, 'id': 'call_q0bvNvfUhPgjFOB5XH9aC2sT', 'type': 'tool_call'}, {'name': 'web_search', 'args': {'query': 'chicken soup with rice recipe'}, 'id': 'call_nmnyS4E1YC9PrDnaZfecDxfU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 202, 'output_tokens': 768, 'total_tokens': 970, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='{"query": "leftover chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.facebook.com/TheRecipeCritic/posts/grab-you-leftover-rice-and-chicken-toss-it-all-in-a-pan-and-boom-dinner-is-ready/1251345426337809/", "title": "Grab you leftover rice and chicken, toss it all in a pan, and ...", "content": "Recipe Ingredients: 2 cups cooked and chilled rice 1 lb chicken breast, cut into small pieces 2 tablespoons vegetable oil 1 small onion", "score": 0.89997756, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.8452414, "raw_content": null}, {"url": "https://www.crazyforcrust.com/chicken-and-rice-casserole/", "title": "EASY Chicken and Rice Casserole", "content": "Home | Recipe Index | Savory | Casserole | Chicken and Rice Casserole. # Chicken and Rice Casserole. This is the best chicken and rice recipe because it’s easy to make with simple ingredients that you can switch up depending on your tastes. It’s what I consider a “leftover” recipe because I use leftover chicken and rice to make it. ## Ingredients for Chicken and Rice Casserole. ## How to make Chicken and Rice Casserole. * I love **peas** in my chicken casserole, but you can swap them out, use **frozen broccoli** instead and call it chicken broccoli and rice casserole. For my chicken and rice casserole you will want to use cooked chicken. ## Chicken and Rice Casserole. Easy Chicken and Rice Casserole is an fast comfort food dinner. Use leftover chicken or turkey and rice to make this cheesy chicken casserole recipe! ### Chicken and Rice Casserole.", "score": 0.84027237, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner", "content": "Leftover Chicken and Rice Recipe For Dinner\\nTracy\'s Cookin’\\n14600 subscribers\\n49 likes\\n7853 views\\n6 May 2022\\nThis Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy Dinner Recipe using leftover food.\\n4 comments\\n", "score": 0.8342047, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - The Best Easy Dinner Recipes", "content": "# Chicken Fried Rice. *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.*. I used leftover rotisserie chicken and leftover rice in this. You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. * **Cold rice** - cold rice makes the best fried rice so use leftover rice or cook the rice the night before. ## How To Make Chicken Fried Rice. * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice. Simple and delicious Chicken F ...
#               ToolMessage(content='{"query": "one-pot chicken and rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://iowagirleats.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice - Family Favorite Recipe", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. **Step 4:** Season **chicken breasts** that have been chopped into bite-sized pieces with **seasoned salt** and **pepper** then add to the soup pot and continue to simmer until the rice is al dente and the chicken is cooked through, 7-10 additional minutes. The dish will thicken as it cools, and you can taste the flavor much better when the chicken and rice is warm vs piping hot, so I like to let the pot sit uncovered for an additional 10 minutes or so before scooping into bowls and serving. Add dried parsley and chicken stock then turn heat up to high to bring to a boil, stirring occasionally to ensure the rice doesn’t stick to the bottom of the pot as it comes to a boil.", "score": 0.94314384, "raw_content": null}, {"url": "https://www.budgetbytes.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice", "content": "This Chicken and Rice one pot meal is the kind of comfort food I make time and time again, and it’s definitely moving to the top of my list of favorite recipes. This super simple dish includes juicy chicken thighs coated in herbs and spices (not spicy!), sautéed onions, and long grain white rice cooked in vegetable broth. Since I didn’t add any vegetables *in* the pot with my chicken and rice, I added some roasted broccoli on the side. This hearty and delicious chicken and rice combines rich and flavorful rice with well seasoned chicken or an easy one pot meal. So easy to try many different types of spice profiles- this would be a great base, for instance- for Spanish rice and chicken one pot meal- just get some tomato bouillon and some tomato paste added after the onions would make a really excellent alternative- season the chicken with adobo, beans as a side etc.", "score": 0.9304142, "raw_content": null}, {"url": "https://www.thedinnerbite.com/one-pot-chicken-and-rice/", "title": "One Pot Chicken and Rice", "content": "# One Pot Chicken and Rice. This **one pot chicken and rice** recipe is about to become your family’s favourite. ## **One pot chicken and rice recipe**. Although both chicken and rice recipes on the blog were made in my Instant Pot pressure cooker, I’m listening to my readers who haven’t yet joined the Instant Pot bandwagon and showing you how I make stovetop one-pan chicken and rice in easy steps. Today’s recipe is similar to my Instant Pot chicken and rice and I hope you enjoy it as much as we did. ## **How to make chicken and rice in one pot in easy steps**. Arrange the chicken thighs over the rice, then cover the pot with its lid and cook on low-medium heat for about 15 to 20 minutes, depending on the type of rice you are using. ### **More rice recipes you will love**. If you made this easy skillet chicken and rice recipe, don’t forget to leave me feedback and rate it 5 stars. ## One Pot Chicken and Rice.", "score": 0.9126935, "raw_content": null}, {"url": "https://www.facebook.com/natashaskitchen/posts/this-one-pot-chicken-and-rice-dish-is-so-satisfying-a-must-try-it-has-all-of-the/1414689763354187/", "title": "This One-Pot Chicken and Rice dish is so satisfying", "content": "Chicken cooked with rice, bamboo shoot, few veggies and flavoured ginger, garlic and sichuan pepper. A very delicious and comforting dish. One", "score": 0.8976328, "raw_content": null}, {"url": "https://www.simplyrecipes.com/one-pot-chicken-and-rice-recipe-8765045", "title": "My Mom\'s One-Pot Chicken and Rice Is Pure Comfort Food", "content": "# My Mom’s One-Pot Chicken and Rice Is Pure Comfort Food. This simple dish of shredded chicken and creamy rice  ...
#               ToolMessage(content='{"query": "chicken fried rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https
rice Casserole. Chicken Rice Casserole makes for a crowd-pleasing dinner that comes together in under 5 minutes of prep time. Made with only 4 ingredients, this dish has juicy chicken breasts and tender rice in a deliciously creamy sauce. There is nothing like Chicken Rice\xa0Casserole for dinner. This easy Chicken Rice Casserole takes about an hour\xa0to bake (depending on your oven, you may need a few extra minutes but for me it’s about an hour), but that is one of the things that make it kind of the perfect dish. ## 4 Ingredient Chicken & Rice Casserole. Chicken Rice Casserole makes for a crowd-pleasing dinner that comes together in under 5 minutes of prep time. 7. This is my very FAVORITE recipe for Chicken and Rice. 8. I am waiting…tick tock…it has been in the oven for almost 2 hours and the chicken is cooked but the rice + mixture is still  ...
#               ToolMessage(content='{"query": "chicken soup with rice recipe", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.acouplecooks.com/chicken-and-rice-soup-recipe/", "title": "Chicken and Rice Soup (Family Favorite!) - A Couple Cooks", "content": "Add the chicken stock, water, whole chicken breasts, rice, oregano, garlic powder, and kosher salt. Bring to a boil, then reduce to a simmer.", "score": 0.9997428, "raw_content": null}, {"url": "https://www.allrecipes.com/recipe/231291/hearty-chicken-and-rice-soup/", "title": "Hearty Chicken and Rice Soup Recipe - Allrecipes", "content": "Hearty Chicken and Rice Soup Recipe. *   Chicken and Rice Soup Recipes. Hearty Chicken and Rice Soup. Add Photo 43 Image 1: Bowl of chicken and rice soup garnished with herbs:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-145-4x3-beauty--0409cff7c355457da1938508cf591195.jpg)43 Image 343 Image 443 Image 5. Image 6:  Ingredients for chicken and rice soup arranged on marble surface:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-122-4x3-step-01-63bb38f5b8da4dbc8194ab61d0b5dc5d.jpg). Image 8: Chicken soup ingredients simmering in a pot on stovetop:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-123-4x3-step-02-4e0208589ca34baba7b4e36662b2ffad.jpg). Image 10: Wooden spoon stirring chicken soup in a pot on stovetop:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-125-4x3-step-03-675326c6b5e84afd9715ba4834d0ea31.jpg). Image 12: Chicken soup thickened with rice in large pot with a wooden spoon :max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-127-4x3-step-04-2d03a90e921e4971b73995dcce2c6898.jpg). Image 14: Bowl of chicken and rice soup garnished with herbs:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-145-4x3-beauty--0409cff7c355457da1938508cf591195.jpg). I was already making chicken soup and turned to this recipe to figure out how much rice to add and saw that lime juice was used. Image 17: Bowl of chicken and rice soup garnished with herbs:max_bytes(150000):strip_icc():format(webp)/231291-hearty-chicken-and-rice-soup-DDMFS-145-4x3-beauty--0409cff7c355457da1938508cf591195.jpg). I was already making chicken soup and turned to this recipe to figure out how much rice to add and saw that lime juice was used.", "score": 0.99962294, "raw_content": null}, {"url": "https://www.saltandlavender.com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Salt & Lavender", "content": "Home Chicken & Poultry Easy Chicken and Rice Soup. # Easy Chicken and Rice Soup. This **chicken and rice soup** recipe is incredibly cozy! You may also like my\xa0Creamy Chicken and Rice Soup. This chicken and rice soup is one of our staples to cook for family when someone is feeling under the weather. ## How to make chicken and rice soup. ## What to serve with chicken and rice soup. If you made this quick and easy chicken soup with rice, please leave a star rating and review below! ## Easy Chicken and Rice Soup. This **chicken and rice soup** recipe is incredibly cozy! * Add the chicken thighs, carrots, chicken broth, Italian seasoning, and rice to the pot. Chicken & Poultry Lighter Options Recipes Soups. 3. Your recipe definitely helped me get started on making a healthy chicken soup for my sick friend!", "score": 0.9996111, "raw_content": null}, {"url": "https://iowagirleats.com/easy-chicken-and-rice-soup/", "title": "Easy Chicken and Rice Soup - Quick and Comforting - Iowa Girl Eats", "content": "# Easy Chicken and Rice Soup. Easy Chicken and Rice Soup is a quick and simple soup recipe that the entire family will love. Soup season is 12 months a year at my house, and the recipe that makes the most appearances – even during the dog days of summer – is my **Chicken and Rice Soup** recipe. This brothy a ...
#               AIMessage(content='Nice—leftover chicken and rice are perfect for quick, comforting meals. Here are several solid options you can choose from (all fairly common to make and great with basic pantry staples):\n\n- One-Pot Creamy Chicken and Rice (stovetop)\n  - Why it’s great: Cozy, creamy texture with minimal cleanup; everything comes together in one pot.\n  - Approx time: 30–40 minutes.\n  - Source idea: Budget Bytes / The Dinner Bite style recipes.\n\n- Chicken Fried Rice (skillet)\n  - Why it’s great: Uses leftover rice crisps up nicely and you can toss in any veggies you’ve got. Very quick.\n  - Approx time: 15–20 minutes.\n  - Source idea: Classic fried rice recipes (RecipeTin Eats, Averie Cooks, etc.).\n\n- Chicken and Rice Casserole (baked)\n  - Why it’s great: Hearty, comforting, and easy to bake in one dish; you can add peas or broccoli for color and nutrition.\n  - Approx time: 45–60 minutes (plus bake time).\n  - Source idea: Various “one-pan” or “casserole” chicken and rice recipes.\n\n- Chicken and Rice Soup (broth-based)\n  - Why it’s great: Light and warming; easy to scale up with more veggies or noodles.\n  - Approx time: 30–45 minutes.\n  - Source idea: Classic chicken and rice soup recipes (some call for cooking the rice separately to keep texture).\n\n- Leftover Chicken and Egg Fried Rice (specific leftover-hack)\n  - Why it’s great: Focused on using leftovers exactly as-is; extra tasty with a few eggs for protein.\n  - Approx time: 15–20 minutes.\n  - Source idea: Leftover chicken and egg fried rice recipes.\n\nWould you like me to pull full step-by-step instructions for one of these? If you tell me which option sounds best (or what ingredients you have on hand besides chicken and rice), I’ll tailor a complete recipe with exact measurements and steps.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1839, 'prompt_tokens': 6403, 'total_tokens': 8242, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsZtgLIPqjNoGRncQfUDIsYFD2GhK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b70c8-5579-7250-a634-637befbca289-0', usage_metadata={'input_tokens': 6403, 'output_tokens': 1839, 'total_tokens': 8242, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}}),
#               HumanMessage(content=[{'type': 'text', 'text': '\n                Tell me what you notice about my refrigerator here?\n\n                Also, from the recipes that you provided, which one is the easiest\n                for me to do if I need to store them in my refrigerator?\n            '}, {'type': 'image', 'base64': '...', 'mime_type': 'image/png'}], additional_kwargs={}, response_metadata={}, id='6d329d88-ce2c-4b60-bff9-cb2b8c781924'),
#               AIMessage(content='Nice, I’ll tackle both parts.\n\nWhat I notice about your refrigerator (from the image)\n- It looks like a compact/apartment-size fridge with a standard interior layout (shelves, a crisper drawer at the bottom, and door shelves).\n- The unit appears clean and mostly empty, which is great for planning leftovers.\n- The door swings open to the left in the photo, with multiple door trays for bottles or small jars.\n- There isn’t visible produce or dairy inside, so you’ve got space to add a few containers of leftovers or prepared meals.\n- Overall, it’s a basic, no-frills fridge that’s easy to organize if you portion food into airtight containers.\n\nWhich of the recipes is the easiest to store in the fridge\n- My pick for easiest storage: Chicken Rice Casserole (the “one-pan baked” option).\n  - Why: It’s a single dish that you can portion out into airtight containers or keep in the baking dish with a lid. It stores well in the fridge for 3–4 days and reheats nicely in the microwave or oven without losing texture.\n- If you’d rather avoid a casserole, the Chicken Fried Rice is also very fridge-friendly: simply store leftovers in an airtight container and reheat in a skillet or microwave. It reheats quickly and doesn’t require separate components.\n- The One-Pot Creamy Chicken and Rice is also convenient for fridge storage, since leftovers stay cohesive in the same pot (just reheat gently with a splash of broth to loosen if needed).\n\nWould you like me to share the full step-by-step recipe for the easiest option (casserole), with exact measurements and a fridge-friendly storage plan? If you tell me how many servings you want to store, I’ll tailor it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2800, 'prompt_tokens': 7033, 'total_tokens': 9833, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2432, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsZwJN6JSjjXouJRf2XU3Nu3xbMtU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b70ca-d1ab-76f3-9f44-a5c09a06e0d0-0', usage_metadata={'input_tokens': 7033, 'output_tokens': 2800, 'total_tokens': 9833, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2432}})]}

# %% [markdown]
# https://smith.langchain.com/public/bf9cb10c-2085-4dc3-887d-4dd771182643/r
