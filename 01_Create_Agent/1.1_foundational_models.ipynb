# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initializing and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

model
# Out:
# ChatOpenAI(profile={'max_input_tokens': 272000, 'max_output_tokens': 128000, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x128b51730>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x12a496810>, root_client=<openai.OpenAI object at 0x11ec811c0>, root_async_client=<openai.AsyncOpenAI object at 0x128b53350>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you’re thinking of a fictional universe, some stories imagine a lunar capital, but in reality none exists. If you have a specific fictional world in mind, tell me and I can check that one.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 583, 'prompt_tokens': 13, 'total_tokens': 596, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsF6i9n7l92XDvP4IQhVn4xxRoZOb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6c04-e959-7e92-9ea7-c765b3e090c1-0', usage_metadata={'input_tokens': 13, 'output_tokens': 583, 'total_tokens': 596, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you’re thinking of a fictional universe, some stories imagine a lunar capital, but in reality none exists. If you have a specific fictional world in mind, tell me and I can check that one.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-CsF6i9n7l92XDvP4IQhVn4xxRoZOb',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 583,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 512,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 596}}

# %% [markdown]
# ## Customizing your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of a fictional setting, some stories invent capitals or lunar cities (like “Lunapolis” or similar), but in reality there’s no capital.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory. It's Earth's natural satellite - a celestial body with no permanent population or government.
#
# If you're asking about something moon-related, perhaps you meant:
# - The first landing site? That would be the Sea of Tranquility (where Apollo 11 landed)
# - A lunar base in science fiction? Many stories feature different fictional capitals
#
# Is there something specific about the Moon you'd like to know?

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-pro-preview")

response = model.invoke("What's the capital of the Moon?")

pprint(response.content)
# Out:
# [{'extras': {'signature': '...'},
#   'text': 'The Moon **does not have a capital.**\n'
#           '\n'
#           'Here is why:\n'
#           '\n'
#           '1.  **No Government:** The Moon is not a country, state, or '
#           'political entity. It has no government and no permanent '
#           'population.\n'
#           '2.  **International Law:** According to the **Outer Space Treaty of '
#           '1967**, which was signed by most nations on Earth, no country can '
#           'claim sovereignty over the Moon. Therefore, it has no '
#           'administrative center.\n'
#           '\n'
#           'However, if you are looking for the most historically significant '
#           'location, many people consider **Tranquillity Base** (the site of '
#           'the Apollo 11 landing) to be the most "important" spot on the Moon, '
#           'but it holds no political status.',
#   'type': 'text'}]

# %% [markdown]
# ## Initializing and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='00da0481-09be-445c-90ce-e430b52b5fe8'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. There are no permanent settlements yet, just missions and prototypes. (In fiction, authors sometimes invent lunar capitals like Lunapolis, but none exist in reality.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 826, 'prompt_tokens': 13, 'total_tokens': 839, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsF78vcloytv50deUaZuM9x6Nay7e', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6c05-4f6f-76e3-b750-7384cdf3d0d2-0', usage_metadata={'input_tokens': 13, 'output_tokens': 826, 'total_tokens': 839, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response["messages"][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. There are no permanent settlements yet, just missions and prototypes. (In fiction, authors sometimes invent lunar capitals like Lunapolis, but none exist in reality.)

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City.")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='99ebf1d6-3fef-47ae-98b3-c2ba117cec96'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='02b19ae5-be09-4ea4-8181-2dd991c329a0'),
#               HumanMessage(content='Interesting, tell me more about Luna City.', additional_kwargs={}, response_metadata={}, id='8d65cfcb-a649-43cd-8187-5625c2882ca1'),
#               AIMessage(content='Luna City is a fictional lunar metropolis you can use for stories, games, or world-building. Here’s a richer picture of what it could be like:\n\n- Location and purpose\n  - Built on the rim of Shackleton crater at the Moon’s south pole to take advantage of nearby water ice and high, sunlit areas.\n  - Designed as a mixed-use hub for science, industry, and culture—part research station, part living city, part international outpost.\n\n- Governance and society\n  - Governed by the International Lunar Authority (ILA) with a Luna City Council representing residents, scientists, engineers, and workers.\n  - Citizenship is earned by residency and contribution to ISRU (in-situ resource utilization), research, or public service.\n  - Multicultural population: scientists, technicians, artists, educators, and families. Many speak a blend of Earth languages; English is common for coordination.\n\n- City layout and districts\n  - The Core: administration, laboratories, university campuses, and the central hive of data centers.\n  - Crescent Market: supply depots, shops, cafes, and cultural venues; a social hub that hosts periodic lunar festivals.\n  - Ice Gate District: water processing facilities, air handling, and cryogenics; critical for life support.\n  - Radiant Heights: residential sectors built into domes and shallow subsurface habitats shielded by regolith.\n  - Subsurface Hub: living quarters and workshops inside shielded tunnels and lava tubes to minimize radiation exposure.\n  - Transit Spine: a ring of vacuum-tube transport and mag-lev corridors that connect districts and a network of surface rovers.\n\n- Architecture and technology\n  - Habitats use 3D-printed regolith shells, with transparent skylights for ambient light and solar shutters to manage heat.\n  - Core technology includes ISRU plants that extract water from ice, generate oxygen, and produce methane for fuel.\n  - Solar farms on sunlit rims and, if needed, compact fission or advanced batteries to smooth power during the long lunar night.\n  - Regolith shielding and radiation-absorbing materials protect inhabitants from space weather and solar events.\n\n- Economy and daily life\n  - Economy driven by ISRU products, scientific instrumentation, space medicine, and lunar construction supplies.\n  - Research and development in lunar geology, biology, and autonomous systems are central to daily life.\n  - Daily life blends practical routines (health checks, maintenance, schooling) with culture: music, art, and interplanetary communications.\n  - Education from primary to university level emphasizes STEM, lunar science, and space ethics.\n\n- Culture, festivals, and landmarks\n  - Notable landmarks might include:\n    - The Observatory Dome, a soaring glass structure for astronomy and public education.\n    - The Ice Gate, a sparkling facility where ice is harvested and purified.\n    - The Echo Spire, a communications and navigation array that helps link Moon and Earth.\n    - Lumen Park, a daylight-filled green space with plastic-free gardens and lunar flora trials.\n  - Festivals celebrate solar events, eclipses, and the enduring collaboration between Earth nations and Moon residents.\n\n- Transportation and exploration\n  - Surface rovers and small electric vehicles navigate crater rims and tunnels.\n  - Vacuum-tube transit and mag-lev corridors connect districts quickly.\n  - Exploration teams venture into lava tubes and near-surface ice deposits, guided by autonomous drones and geologists.\n\n- Environment, health, and ethics\n  - Environmental controls manage dust, radiation, and resource usage to minimize ecological footprint.\n  - Mental health programs emphasize community, art, and outdoor time during the long lunar days.\n  - Ethical focus on sharing resources equitably, protecting lunar heritage sites, and avoiding over-exploitation of ISRU.\n\n- Challenges and future plans\n  - Logistics: maintaining life support, dealing w ...

# %%
print(response["messages"][-1].content)
# Out:
# Luna City is a fictional lunar metropolis you can use for stories, games, or world-building. Here’s a richer picture of what it could be like:
#
# - Location and purpose
#   - Built on the rim of Shackleton crater at the Moon’s south pole to take advantage of nearby water ice and high, sunlit areas.
#   - Designed as a mixed-use hub for science, industry, and culture—part research station, part living city, part international outpost.
#
# - Governance and society
#   - Governed by the International Lunar Authority (ILA) with a Luna City Council representing residents, scientists, engineers, and workers.
#   - Citizenship is earned by residency and contribution to ISRU (in-situ resource utilization), research, or public service.
#   - Multicultural population: scientists, technicians, artists, educators, and families. Many speak a blend of Earth languages; English is common for coordination.
#
# - City layout and districts
#   - The Core: administration, laboratories, university campuses, and the central hive of data centers.
#   - Crescent Market: supply depots, shops, cafes, and cultural venues; a social hub that hosts periodic lunar festivals.
#   - Ice Gate District: water processing facilities, air handling, and cryogenics; critical for life support.
#   - Radiant Heights: residential sectors built into domes and shallow subsurface habitats shielded by regolith.
#   - Subsurface Hub: living quarters and workshops inside shielded tunnels and lava tubes to minimize radiation exposure.
#   - Transit Spine: a ring of vacuum-tube transport and mag-lev corridors that connect districts and a network of surface rovers.
#
# - Architecture and technology
#   - Habitats use 3D-printed regolith shells, with transparent skylights for ambient light and solar shutters to manage heat.
#   - Core technology includes ISRU plants that extract water from ice, generate oxygen, and produce methane for fuel.
#   - Solar farms on sunlit rims and, if needed, compact fission or advanced batteries to smooth power during the long lunar night.
#   - Regolith shielding and radiation-absorbing materials protect inhabitants from space weather and solar events.
#
# - Economy and daily life
#   - Economy driven by ISRU products, scientific instrumentation, space medicine, and lunar construction supplies.
#   - Research and development in lunar geology, biology, and autonomous systems are central to daily life.
#   - Daily life blends practical routines (health checks, maintenance, schooling) with culture: music, art, and interplanetary communications.
#   - Education from primary to university level emphasizes STEM, lunar science, and space ethics.
#
# - Culture, festivals, and landmarks
#   - Notable landmarks might include:
#     - The Observatory Dome, a soaring glass structure for astronomy and public education.
#     - The Ice Gate, a sparkling facility where ice is harvested and purified.
#     - The Echo Spire, a communications and navigation array that helps link Moon and Earth.
#     - Lumen Park, a daylight-filled green space with plastic-free gardens and lunar flora trials.
#   - Festivals celebrate solar events, eclipses, and the enduring collaboration between Earth nations and Moon residents.
#
# - Transportation and exploration
#   - Surface rovers and small electric vehicles navigate crater rims and tunnels.
#   - Vacuum-tube transit and mag-lev corridors connect districts quickly.
#   - Exploration teams venture into lava tubes and near-surface ice deposits, guided by autonomous drones and geologists.
#
# - Environment, health, and ethics
#   - Environmental controls manage dust, radiation, and resource usage to minimize ecological footprint.
#   - Mental health programs emphasize community, art, and outdoor time during the long lunar days.
#   - Ethical focus on sharing resources equitably, protecting lunar heritage sites, and avoiding over-exploitation of ISRU.
#
# - Challenges and future plans
#   - Logistics: maintaining life support, dealing with power storage for the long lunar night, dust management.
#   - Safety: shielding from radiation, micrometeoroids, and debris.
#   - Expansion: plans for intercity links with other lunar settlements, more diverse habitats, and broader ISRU capabilities.
#
# If you’d like, I can tailor Luna City to a specific vibe (e.g., a gritty corporate outpost, a utopian scientific colony, or a rugged frontier town), era (early raid-era settlement vs. mature city in a far-future), or give you sample scenes, character bios, or a short story set there. What tone or details would you prefer?

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Mooon")]},
    stream_mode="messages"
):
    # token is a message chunk with token content
    # metadata contains which node produced the token

    if token.content: # Check if there's actual content
        print(token.content, end="", flush=True) # Print token
# Out:
# Here’s a detailed, ready-to-use concept for Luna City, the capital of the Mooon. Since this isn’t a real-world place, you can treat it as a fully fleshed-out fictional setting or adapt it to your story, game, or world.
#
# Quick pitch
# - Name: Luna City
# - Capital of: The Mooon polity (a lunar nation/colony federation that operates a lunar civilization beyond Earth)
# - Population: roughly 3–6 million residents in domed and subterranean habitats
# - Vibe: a high-tech, resilient, culture-rich capital where politics, research, mining, and culture collide in gleaming domes, glass tunnels, and lava-tube neighborhoods
#
# Geography and environment
# - Location: A near-side lunar basin that’s been terraformed for surface habitations around the Ring Spire, with access to subsurface lava tubes for protection and expansion.
# - Topography: A network of interconnected lava tubes deep beneath the surface that host residential districts, farms, and industry. Surface zones are shielded by domes and radiation barriers, with green-blue bio-luminescent landscaping and reflective solar canopies.
# - Climate and atmosphere: No natural atmosphere; life support is continuous. Day-night cycle is simulated inside habitats. Radiation shielding and dust mitigation are built into every surface.
# - Water and resources: Water ice mined from permanently shadowed craters feeds life-support systems and agriculture; Helium-3 and silicate materials are mined or processed on-site; solar and nuclear fusion power plants supply the city.
#
# History and origin
# - Founding era: Began as a rigid mining outpost for Helium-3 during the early days of lunar exploration. Rapid growth followed the discovery that lunar ice could sustain long-term habitation.
# - Growth milestones:
#   - The Night of Quiet Glass: a solar flare event that forced a decade-long upgrade to transparent shielding and glazing that doubled as energy collectors and public lighting.
#   - The Unification Accord: a formal treaty uniting scattered lunar settlements into the Mooon polity, with Luna City as its administrative heart.
#   - The Golden Dome Initiative: a wave of domed districts and greenhouses that turned Luna City into a living, breathing urban organism.
# - Present role: The central government, science and research hubs, major spaceport, finance, and cultural capital. Serves as the hub for lunar diplomacy with Earth and other moon settlements.
#
# Government and politics
# - Political system: A semi-federal lunar confederation with a bicameral legislature (Craters’ Assembly) and an executive Council. Sectors (districts) elect representatives; certain strategic posts are appointed by a Governor-General and a rotating Speaker of the Craters.
# - Key institutions:
#   - The Beacon Spire: The central government building and the symbolic heart of Luna City; houses the Prime Council, the judicial conclave, and the central archive.
#   - The Archive of Craterion: A vast repository of lunar history, scientific data, and interstellar protocols.
#   - Lunar Security Directorate: Oversees civil defense, cyber defense, and interplanetary security coordination.
#   - Lunar Commerce Authority: Regulates currency, trade with Earth, mining licenses, and resource distribution.
# - Civil society and politics: A mix of technocrats, engineers, scientists, and trade workers. Influence from corporate mining guilds and independent scientists runs strong. Civic festivals double as political forums.
# - Earth-Mooon relations: Earth remains a powerful partner, but Luna City supports a growing sense of lunar autonomy. There are ongoing debates about autonomy vs. federation vs. full independence.
#
# Economy and currency
# - Primary industries:
#   - Helium-3 and other lunar resources (water ice, silicates, rare earths) processed in situ or exported to Earth.
#   - High-precision manufacturing and 3D printing for space hardware, tools, and habitat components.
#   - Research and development: microgravity science, biotech, nanotech, and materials science.
#   - Tourism and culture: zero-g entertainment, glass-domed sightseeing, historical tours of lunar mining history, space festivals.
# - Energy: A mixed system of solar arrays, nuclear fusion micro-turbines, and energy storage nodes; power is distributed through a city-wide microgrid that can island in emergencies.
# - Currency and finance: The main currency is the Luma Credit (LC), with strong reserves in Earth-backed bonds and lunar commodities. A central bank maintains inflation control and interplanetary exchange rates.
#
# Infrastructure and urban design
# - City layout: A multi-ring design surrounding the Beacon Spire. Inner core hosts government districts and central utilities; mid-rings house research institutes, hospitals, and high-end residences; outer rings contain factories, schools, and mixed-use neighborhoods.
# - Housing: Dome and tunnel living; modular apartments with adaptable interiors. Many neighborhoods have vertical farms and hydroponic balconies.
# - Transportation:
#   - Surface maglev tram networks and gravity-assisted shuttles.
#   - Skybridges and light tunnels connect domes; personal Aerial-Transit Pods (ATPs) glide between districts.
#   - Lava-tube transit corridors offer year-round climate control and privacy from surface dust.
# - Water and food: Closed-loop water recycling; lunar greenhouses; hydroponic farms integrated into residential blocks.
# - Public spaces: Glow parks with bioluminescent flora, reflective glass walkways, and art installations powered by ambient solar energy.
#
# Architecture and aesthetics
# - Style: Functional futurism with a touch of lunar-glass elegance. Curved, wind- and dust-resistant shapes dominate; transparent walls on some districts allow starlight with privacy barriers.
# - Materials: A mix of reinforced regolith bricks, transparent aluminum, graphene composites, and self-healing polymers. Surfaces incorporate radiation-shielding tiling and solar-harvesting skins.
# - Landmarks:
#   - The Beacon Spire: 800–1200 meters tall, acts as the city’s nerve center and symbol of lunar sovereignty.
#   - The Helix Dome: A double-helix greenhouse complex providing food and research storage.
#   - The Pulse Observatory: A large telescope complex and public science center.
#   - The Archives of Craterion: An enormous underground archive carved into basalt with a glass ceiling that doubles as a skylight for lunar phases.
#   - The Garden of Echoes: A tranquil, semi-subterranean park featuring reflective pools that map the lunar day-night cycle.
#
# Culture, society, and daily life
# - Demographics: Multinational population driven by migration from Earth and other lunar settlements; diverse languages with Lunarian as a lingua franca and Earth languages common in commerce and diplomacy.
# - Language and communication: Lunarian (a creole-influenced language blending Earth languages with lunar slang), plus English, Mandarin, Hindi, Spanish in business and education contexts.
# - Holidays and rituals:
#   - Long Night Festival: lights, glow-drafts, storytelling, and zero-g performances during the long lunar night.
#   - Harvest of Ice: ritual celebrating seasonal water ice collection and the engineers who make life support possible.
#   - Founders’ Day: commemorates the early outpost pioneers and the unification accord.
# - Cuisine: A fusion of Earth cuisines adapted for hydroponic herbs, farmed crabs from lunar bays, algae-based proteins, and nutrient-dense smoothies. Moon-bloom tea is popular in public squares.
# - Education and research: The Lunar University network includes engineering, life sciences, space medicine, robotics, and lunar archaeology. Public labs and citizen-science programs are common.
# - Religion and belief: A secular to pluralistic approach, with small spiritual communities centered on space and cosmic curiosity; some groups celebrate “the vacuum” as a metaphor for human potential, while others follow Earth-origin religions adapted for space life.
# - Sports and recreation: Zero-G athletics, weightless drone racing, and gravity-assisted hiking on cliff balconies around domed parks.
#
# Landmarks and must-see places
# - The Beacon Spire: The political heart; a symbol of lunar governance and a hub for diplomacy with Earth.
# - The Pulse Observatory: Public telescope complex and research node; hosts nightly starwatch events.
# - The Gardens of Echoes: Serene, subterranean gardens with reflective surfaces and lunar-themed art.
# - The Archives of Craterion: A trove of lunar history and technical blueprints; accessible to researchers and students.
# - The Helix Dome: Agricultural and biotechnical research facility with towering vertical farms.
# - The Lunar Port: A spaceport and commercial hub with shuttle lanes to Earth and other moons or stations.
#
# Challenges, conflicts, and drama hooks
# - Resource pressure: Competition for rare isotopes and water ice in polar regions; debates about mining ethics and environmental impact inside the Moon.
# - Political factionalism: Tensions between technocrats who prioritize efficiency and workers who demand fair wages and safer living conditions.
# - Radiation and dust events: Solar storms, micrometeorite dust storms, and shielding maintenance scheduling create crisis scenarios and plots.
# - Earth-Mooon dynamics: Shifting alliances, trade disputes, and space policy disagreements fuel political intrigue.
# - Social strains: Migration, housing shortages in peak seasons, and cultural identity politics between long-time lunar residents and newcomers.
#
# Notable characters and roles (inspiration)
# - Governor-general Aria Kline: Pragmatic leader advocating for lunar autonomy while maintaining Earth partnerships.
# - Chief Archivist Ryo Nakamura: Guardian of Craterion and head of the Archives, a genius with a knack for discovering forgotten lunar histories.
# - Head Engineer Mara Solis: Oversees energy networks and habitat infrastructure; a pioneer in self-healing materials.
# - Captain Juno Ryker: Starfleet-like captain in charge of the Lunar Port’s security and interplanetary transport safety.
# - Dr. Leena Idris: Biotechnologist developing sustainable crops for lunar agriculture and life-support systems.
#
# Story seeds you can use
# - A diplomatic crisis on the eve of a major Earth-Mooon treaty signing disrupts energy supplies, forcing Luna City to improvise a solution in under 48 hours.
# - A mystery in the Archives of Craterion reveals a hidden chapter of lunar history that could reshape lunar identity and policy.
# - A controversial housing project threatens to erase a traditional Lunarian neighborhood; protests erupt in the glow parks.
# - A rare hydrosphere anomaly in a polar crater opens new life-support breakthroughs but invites ethical debates about resource extraction and planetary protection.
#
# Two quick tone-shaping options (pick one or blend)
# - Hard SF realism: Emphasize physics, engineering constraints, and procedural details (e.g., power grids, life support, radiation shielding, lunar logistics, supply chains).
# - Lyrical, explorer vibe: Focus on culture, architecture, personal stories, and the emotional texture of living on the Moon, with vivid imagery of domes, night skies, and day-night cycles.
#
# If you want, I can tailor Luna City to a specific genre (hard sci-fi, space opera, noir detective on the Moon, YA adventure, etc.), or adjust details like population size, tech level, ruling system, or geography to fit your project. Tell me the tone you’re aiming for, and any constraints (word count, platform, audience), and I’ll adapt Luna City accordingly.
