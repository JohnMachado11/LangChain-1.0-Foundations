# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response["messages"][-1].content)
# Out:
# London Breed. She has been the mayor since 2018 and was re-elected in 2022, serving a term through 2027. If you want, I can provide a quick bio or recent news.

# %%
question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response["messages"][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access, so I can’t fetch or verify events after that unless you provide current information. I can help interpret, summarize, or reason about topics using my existing knowledge, and I can work with any new details you share. If you need the latest facts, share sources or links and I can help analyze them.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """
    Search the web for information
    """
    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9994253,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.9993538,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.99620515,
#    'raw_content': None},
#   {'url': 'https://www.cbsnews.com/sanfrancisco/news/san-francisco-mayor-elect-daniel-lurie-claims-victory-outlines-vision-for-city/',
#    'title': 'San Francisco Mayor-elect Daniel Lurie claims victory ... - CBS News',
#    'content': "San Francisco's Mayor-elect Daniel Lurie declared victory Friday morning as he addressed the city for the first time since incumbent Mayor London Breed",
#    'score': 0.9942697,
#    'raw_content': None},
#   {'url': 'https://www.youtube.com/watch?v=Qvl6AMoZCoI',
#    'title': 'San Francisco Mayor-elect Daniel Lurie on transforming the city',
#    'content': "In a CNBC exclusive, San Francisco's new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,",
#    'score': 0.9921233,
#    'raw_content': None}],
#  'response_time': 0.73,
#  'request_id': '53ef3c24-40a0-4e72-ada4-7d1dee729f69'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response["messages"])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='65d06b65-f76f-4e4d-bc9a-0457eb676e31'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 478, 'prompt_tokens': 133, 'total_tokens': 611, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsKHIUVD158tvagWIgvS6wT8b87RB', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6d34-31d3-7600-af50-a967e0362252-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco 2025'}, 'id': 'call_xiMiQh8eTt4BJNZ5TSXbF0CC', 'type': 'tool_call'}], usage_metadata={'input_tokens': 133, 'output_tokens': 478, 'total_tokens': 611, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco 2025", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.latimes.com/california/story/2025-01-08/daniel-lurie-inaugurated-as-san-francisco-mayor", "title": "Daniel Lurie inaugurated as San Francisco\'s new mayor", "content": "Levi Strauss heir and nonprofit executive Daniel Lurie was sworn in Wednesday as the 46th mayor of San Francisco. He vowed a \\"new era of", "score": 0.99821776, "raw_content": null}, {"url": "https://www.sfchronicle.com/sf/article/daniel-lurie-was-sworn-in-as-s-f-mayor-20013863.php", "title": "Daniel Lurie was sworn in as S.F. mayor. Here\'s what he\'ll ...", "content": "Mayor-elect Daniel Lurie is sworn in as Mayor in San Francisco on Wednesday, January 8, 2025.", "score": 0.9976769, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=G5kDdDF9NW4", "title": "Daniel Lurie inaugurated as San Francisco\'s 46th mayor ...", "content": "Daniel Lurie inaugurated as San Francisco\'s 46th mayor: FULL VIDEO ... Mayor Daniel Lurie & District 4 Supervisor Beya Alcaraz on 11/12/2025.", "score": 0.99732697, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco", "content": "Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco ; Incumbent Daniel Lurie. since January 8, 2025. Government of San Francisco · His", "score": 0.9959927, "raw_content": null}, {"url": "https://www.politico.com/news/magazine/2025/02/23/daniel-lurie-san-francisco-mayor-00205527", "title": "Mayor Lurie Tries to Bloomberg-ize San Francisco", "content": "SAN FRANCISCO — Daniel Lurie began the morning of his inauguration as this city\'s new mayor last month at a soup kitchen before walking with", "score": 0.9950563, "raw_content": null}], "response_time": 0.74, "request_id": "4728f1cf-2e8a-4603-b421-974266b1069d"}', name='web_search', id='f32a245d-aa3a-4590-8ec2-1e5acce94f80', tool_call_id='call_xiMiQh8eTt4BJNZ5TSXbF0CC'),
#  AIMessage(content="Daniel Lurie is the current mayor of San Francisco. He was sworn in in January 2025 as the city’s 46th mayor.\n\nSources:\n- Los Angeles Times: Daniel Lurie inaugurated as San Francisco's new mayor (Jan 8, 2025)\n- San Francisco Chronicle: Daniel Lurie was sworn in as S.F. mayor (Jan 8, 2025)", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 985, 'prompt_tokens': 736, 'total_tokens': 1721, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CsKHOpLW9IDvcp7TAeE4A29p7FiA1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6d34-4a7f-77e3-b056-e59dc6c22ced-0', usage_metadata={'input_tokens': 736, 'output_tokens': 985, 'total_tokens': 1721, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})]

# %% [markdown]
# https://smith.langchain.com/public/46d2dc05-1485-42fc-bd73-f4ff94c5d9e4/r
